# %% [markdown]
# # I. PEMAHAMAN DOMAIN DAN TUJUAN

# %% [markdown]
# ## 1.1. Pemahaman Penyakit Ginjal Kronis

# %% [markdown]
# Penyakit Ginjal Kronis (PGK) adalah suatu proses patofisiologis dengan etiologi yang beragam, mengakibatkan penurunan fungsi ginjal yang progresif, penurunan fungsi ini bersifat kronis dan irreversible.
#
# Data didapatkan dari UCI Machine Learning Repository. Berisikan 400 data dan memiliki 25 atribut, terdiri dari 1 kelas target dan 24 atribut.

# %% [markdown]
# ## 1.2. Tujuan

# %% [markdown]
# Identifikasi PGK dengan atribut yang paling berpengaruh

# %% [markdown]
# # II. PEMBUATAN DATASET DAN TARGET

# %% [markdown]
# ## 2.1 Data UCI

# %% [markdown]
# Data didapat dari: https://archive.ics.uci.edu/ml/datasets/chronic_kidney_disease
#
# Data tersebut di-import dalam mariaDB

# %% [raw]
# >Import Library

# %%
import numpy as np
import pandas as pd
import pymysql as pskl
import matplotlib.pyplot as plt

# Menampilkan semua array
# np.set_printoptions(threshold=np.nan)

# %% [raw]
# >Memanggil Dataset

# %%
def dataset(retrieve="numeric", id=0, target=0): #hasil bertipe dataframe
    """
    parameters
    ----------
    retrieve: (all, numeric, polinom)
        all    : semua kolom
        numeric: hanya kolom numeric
        polinom: hanya kolom polinom
    id: (0, 1)
        0: tanpa kolom id
        1: dengan kolom id
    class: (0, 1)
        0: tanpa kolom class
        1: dengan kolom class
    
    """
    connection = pskl.connect(host="localhost", user="root", passwd="", database="knn")
    cursor = connection.cursor()
    if(retrieve=="all"):
        cols = ["id", "age", "bp", "sg", "al", "su", "bgr", "bu", "sc", "sod", "pot", "hemo", "pcv", "wbcc", "rbcc", "rbc", "pc", "pcc", "ba", "htn", "dm", "cad", "appet", "pe", "ane", "class"]
        retrieve = "SELECT id, age, bp, sg, al, su, bgr, bu, sc, sod, pot, hemo, pcv, wbcc, rbcc, rbc, pc, pcc, ba, htn, dm, cad, appet, pe, ane, class FROM ckd_preprocessing3"
    elif(retrieve=="numeric"):
        cols = ["id", "age", "bp", "sg", "al", "su", "bgr", "bu", "sc", "sod", "pot", "hemo", "pcv", "wbcc", "rbcc", "class"]
        retrieve = "SELECT id, age, bp, sg, al, su, bgr, bu, sc, sod, pot, hemo, pcv, wbcc, rbcc, class FROM ckd_preprocessing3"
    elif(retrieve=="polinom"):
        cols = ["id", "rbc", "pc", "pcc", "ba", "htn", "dm", "cad", "appet", "pe", "ane", "class"]
        retrieve = "SELECT id, rbc, pc, pcc, ba, htn, dm, cad, appet, pe, ane, class FROM ckd_preprocessing3"
    resolveall = cursor.execute(retrieve)
    rows_tupple = cursor.fetchall()
    data = pd.DataFrame(list(rows_tupple))
    data.columns = cols
    if(id==0):
        data = data.drop(["id"], axis=1)
    if(target==0):
        data = data.drop(["class"], axis=1)
    data = data.fillna(value=np.nan) #mengubah missing value menjadi NaN
    return data

# %%
dataset(retrieve="all").head(10)
# Out:
#     age     bp     sg   al   su    bgr     bu    sc    sod  pot ...   \
# 0  48.0   80.0  1.020  1.0  0.0  121.0   36.0   1.2    NaN  NaN ...
# 1   7.0   50.0  1.020  4.0  0.0    NaN   18.0   0.8    NaN  NaN ...
# 2  62.0   80.0  1.010  2.0  3.0  423.0   53.0   1.8    NaN  NaN ...
# 3  48.0   70.0  1.005  4.0  0.0  117.0   56.0   3.8  111.0  2.5 ...
# 4  51.0   80.0  1.010  2.0  0.0  106.0   26.0   1.4    NaN  NaN ...
# 5  60.0   90.0  1.015  3.0  0.0   74.0   25.0   1.1  142.0  3.2 ...
# 6  68.0   70.0  1.010  0.0  0.0  100.0   54.0  24.0  104.0  4.0 ...
# 7  24.0    NaN  1.015  2.0  4.0  410.0   31.0   1.1    NaN  NaN ...
# 8  52.0  100.0  1.015  3.0  0.0  138.0   60.0   1.9    NaN  NaN ...
# 9  53.0   90.0  1.020  2.0  0.0   70.0  107.0   7.2  114.0  3.7 ...
#
#         rbc        pc         pcc          ba  htn   dm cad appet   pe  ane
# 0       NaN    normal  notpresent  notpresent  yes  yes  no  good   no   no
# 1       NaN    normal  notpresent  notpresent   no   no  no  good   no   no
# 2    normal    normal  notpresent  notpresent   no  yes  no  poor   no  yes
# 3    normal  abnormal     present  notpresent  yes   no  no  poor  yes  yes
# 4    normal    normal  notpresent  notpresent   no   no  no  good   no   no
# 5       NaN       NaN  notpresent  notpresent  yes  yes  no  good  yes   no
# 6       NaN    normal  notpresent  notpresent   no   no  no  good   no   no
# 7    normal  abnormal  notpresent  notpresent   no  yes  no  good  yes   no
# 8    normal  abnormal     present  notpresent  yes  yes  no  good   no  yes
# 9  abnormal  abnormal     present  notpresent  yes  yes  no  poor   no  yes
#
# [10 rows x 24 columns]

# %% [markdown]
# ## 2.2. Menentukan Atribut Target

# %% [markdown]
# Atribut "class" sebagai target dataset

# %% [markdown]
# # III. DATA CLEANING DAN PREPROCESSING

# %% [markdown]
# ## 3.1 Menghilangkan Outliers

# %% [markdown]
# referensi: http://digilib.unila.ac.id/20585/4/II.%20TINJAUAN%20PUSTAKA.pdf

# %%
def outliers(df, k1=0.25, k3=0.75):
    """
    parameters:
    -----------
    df: input tipe dataframe, hanya menerima numeric
    
    mendeteksi data yang diluar batas bawah dan batas atas
    batas bawah = k1 - (k3-k1)*1.5
    batas atas = k3 + (k3-k1)*1.5
    """
    pencilan = df.apply(lambda x: (x < df[x.name].quantile(k1)-((df[x.name].quantile(k3)-df[x.name].quantile(k1))*1.5))|(x > df[x.name].quantile(k3)+((df[x.name].quantile(k3)-df[x.name].quantile(k1))*1.5)), axis=0)
    return pencilan

# %%
df = dataset()
pencilan = outliers(df)
pencilan.head()
# Out:
#      age     bp     sg     al     su    bgr     bu     sc    sod    pot  \
# 0  False  False  False  False  False  False  False  False  False  False
# 1   True   True  False  False  False  False  False  False  False  False
# 2  False  False  False  False   True   True  False  False  False  False
# 3  False  False  False  False  False  False  False  False   True  False
# 4  False  False  False  False  False  False  False  False  False  False
#
#     hemo    pcv   wbcc   rbcc
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False  False  False
# 4  False  False  False  False

# %%
def outliers_removing(df, pencilan):
    """
    paramters:
    ----------
    df: input tipe dataframe, mengembalikan bentuk asli
    outliers: input tipe dataframe, bertipe boolean
    
    mengembalikan dataframe awal kemudian menghilangkan semua outliers (semua baris yang berisi nilai true)
    """
    filtered_df = df[~(pencilan).any(axis=1)]
    return filtered_df

# %%
df = dataset(retrieve="all", id=1)

filtered_df = outliers_removing(df, pencilan)
filtered_df.head()
# Out:
#     id   age    bp     sg   al   su    bgr    bu   sc    sod ...     rbc  \
# 0    1  48.0  80.0  1.020  1.0  0.0  121.0  36.0  1.2    NaN ...     NaN
# 4    5  51.0  80.0  1.010  2.0  0.0  106.0  26.0  1.4    NaN ...  normal
# 5    6  60.0  90.0  1.015  3.0  0.0   74.0  25.0  1.1  142.0 ...     NaN
# 13  14  68.0  70.0    NaN  NaN  NaN   98.0  86.0  4.6  135.0 ...     NaN
# 16  17  47.0  70.0  1.015  2.0  0.0   99.0  46.0  2.2  138.0 ...     NaN
#
#         pc         pcc          ba  htn   dm  cad appet   pe ane
# 0   normal  notpresent  notpresent  yes  yes   no  good   no  no
# 4   normal  notpresent  notpresent   no   no   no  good   no  no
# 5      NaN  notpresent  notpresent  yes  yes   no  good  yes  no
# 13     NaN  notpresent  notpresent  yes  yes  yes  poor  yes  no
# 16  normal  notpresent  notpresent   no   no   no  good   no  no
#
# [5 rows x 25 columns]

# %% [markdown]
# # IV. TRANSFORMASI DATA

# %% [markdown]
# ## 4.1 Data Nominal Menjadi Numeric

# %% [markdown]
# Mengubah atribut / kolom polinom menjadi numerik
#
# Dikarenakan semua kolom nominal hanya memiliki 2 kelas, dapat di transformasi menjadi 0 dan 1

# %%
from sklearn.preprocessing import LabelEncoder

# %%
filtered_df["rbc"].value_counts()
# Out:
# normal      153
# abnormal     14
# Name: rbc, dtype: int64

# %%
filtered_df["pc"].value_counts()
# Out:
# normal      196
# abnormal     22
# Name: pc, dtype: int64

# %%
filtered_df["pcc"].value_counts()
# Out:
# notpresent    236
# present        11
# Name: pcc, dtype: int64

# %%
filtered_df["ba"].value_counts()
# Out:
# notpresent    241
# present         6
# Name: ba, dtype: int64

# %%
filtered_df["htn"].value_counts()
# Out:
# no     200
# yes     49
# Name: htn, dtype: int64

# %%
filtered_df["dm"].value_counts()
# Out:
# no     207
# yes     42
# Name: dm, dtype: int64

# %%
filtered_df["cad"].value_counts()
# Out:
# no     241
# yes      8
# Name: cad, dtype: int64

# %%
filtered_df["appet"].value_counts()
# Out:
# good    224
# poor     26
# Name: appet, dtype: int64

# %%
filtered_df["pe"].value_counts()
# Out:
# no     220
# yes     30
# Name: pe, dtype: int64

# %%
filtered_df["ane"].value_counts()
# Out:
# no     235
# yes     15
# Name: ane, dtype: int64

# %%
filtered_df.dtypes
# Out:
# id         int64
# age      float64
# bp       float64
# sg       float64
# al       float64
# su       float64
# bgr      float64
# bu       float64
# sc       float64
# sod      float64
# pot      float64
# hemo     float64
# pcv      float64
# wbcc     float64
# rbcc     float64
# rbc       object
# pc        object
# pcc       object
# ba        object
# htn       object
# dm        object
# cad       object
# appet     object
# pe        object
# ane       object
# dtype: object

# %%
filtered_df["pcv"].dtypes
# Out:
# dtype('float64')

# %%
len(filtered_df.columns)
# Out:
# 25

# %%
filtered_df.iloc[:,0].dtypes
# Out:
# dtype('int64')

# %%
for i in range(len(filtered_df.columns)):
    print(filtered_df.iloc[:,i].dtypes)
# Out:
# int64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object

# %%
filtered_df.dtypes
# Out:
# id         int64
# age      float64
# bp       float64
# sg       float64
# al       float64
# su       float64
# bgr      float64
# bu       float64
# sc       float64
# sod      float64
# pot      float64
# hemo     float64
# pcv      float64
# wbcc     float64
# rbcc     float64
# rbc       object
# pc        object
# pcc       object
# ba        object
# htn       object
# dm        object
# cad       object
# appet     object
# pe        object
# ane       object
# dtype: object

# %%
encode = LabelEncoder()
filtered_df
# Out:
#       id   age    bp     sg   al   su    bgr     bu    sc    sod ...   \
# 0      1  48.0  80.0  1.020  1.0  0.0  121.0   36.0  1.20    NaN ...
# 4      5  51.0  80.0  1.010  2.0  0.0  106.0   26.0  1.40    NaN ...
# 5      6  60.0  90.0  1.015  3.0  0.0   74.0   25.0  1.10  142.0 ...
# 13    14  68.0  70.0    NaN  NaN  NaN   98.0   86.0  4.60  135.0 ...
# 16    17  47.0  70.0  1.015  2.0  0.0   99.0   46.0  2.20  138.0 ...
# 17    18  47.0  80.0    NaN  NaN  NaN  114.0   87.0  5.20  139.0 ...
# 19    20  62.0  60.0  1.015  1.0  0.0  100.0   31.0  1.60    NaN ...
# 23    24  21.0  70.0  1.010  0.0  0.0    NaN    NaN   NaN    NaN ...
# 25    26  61.0  60.0  1.025  0.0  0.0  108.0   75.0  1.90  141.0 ...
# 26    27  75.0  80.0  1.015  0.0  0.0  156.0   45.0  2.40  140.0 ...
# 29    30  68.0  70.0  1.005  1.0  0.0    NaN   28.0  1.40    NaN ...
# 31    32  73.0  90.0  1.015  3.0  0.0  107.0   33.0  1.50  141.0 ...
# 36    37  76.0  70.0  1.015  1.0  0.0   92.0   29.0  1.80  133.0 ...
# 37    38  72.0  80.0    NaN  NaN  NaN  137.0   65.0  3.40  141.0 ...
# 38    39  69.0  80.0  1.020  3.0  0.0    NaN  103.0  4.10  132.0 ...
# 40    41  46.0  90.0  1.010  2.0  0.0   99.0   80.0  2.10    NaN ...
# 41    42  45.0  70.0  1.010  0.0  0.0    NaN   20.0  0.70    NaN ...
# 46    47  48.0  70.0  1.015  0.0  0.0  124.0   24.0  1.20  142.0 ...
# 47    48  11.0  80.0  1.010  3.0  0.0    NaN   17.0  0.80    NaN ...
# 50    51  53.0  60.0    NaN  NaN  NaN   91.0  114.0  3.25  142.0 ...
# 52    53  53.0  90.0  1.015  0.0  0.0    NaN   38.0  2.20    NaN ...
# 55    56  35.0  80.0  1.005  3.0  0.0    NaN    NaN   NaN    NaN ...
# 62    63  15.0  60.0  1.020  3.0  0.0   86.0   15.0  0.60  138.0 ...
# 64    65  55.0  80.0  1.010  0.0  0.0  146.0    NaN   NaN    NaN ...
# 65    66  44.0  90.0  1.010  1.0  0.0    NaN   20.0  1.10    NaN ...
# 66    67  67.0  70.0  1.020  2.0  0.0  150.0   55.0  1.60  131.0 ...
# 68    69  65.0  70.0  1.010  2.0  0.0  112.0   73.0  3.30    NaN ...
# 71    72  46.0  60.0  1.010  1.0  0.0  163.0   92.0  3.30  141.0 ...
# 77    78  67.0  70.0  1.010  1.0  0.0  102.0   48.0  3.20  137.0 ...
# 78    79  70.0  80.0    NaN  NaN  NaN  158.0   85.0  3.20  141.0 ...
# ..   ...   ...   ...    ...  ...  ...    ...    ...   ...    ... ...
# 370  371  69.0  70.0  1.020  0.0  0.0   83.0   42.0  1.20  139.0 ...
# 371  372  28.0  60.0  1.025  0.0  0.0   79.0   50.0  0.50  145.0 ...
# 372  373  72.0  60.0  1.020  0.0  0.0  109.0   26.0  0.90  150.0 ...
# 373  374  61.0  70.0  1.025  0.0  0.0  133.0   38.0  1.00  142.0 ...
# 374  375  79.0  80.0  1.025  0.0  0.0  111.0   44.0  1.20  146.0 ...
# 375  376  70.0  80.0  1.020  0.0  0.0   74.0   41.0  0.50  143.0 ...
# 376  377  58.0  70.0  1.025  0.0  0.0   88.0   16.0  1.10  147.0 ...
# 377  378  64.0  70.0  1.020  0.0  0.0   97.0   27.0  0.70  145.0 ...
# 378  379  71.0  60.0  1.025  0.0  0.0    NaN    NaN  0.90  140.0 ...
# 379  380  62.0  80.0  1.025  0.0  0.0   78.0   45.0  0.60  138.0 ...
# 380  381  59.0  60.0  1.020  0.0  0.0  113.0   23.0  1.10  139.0 ...
# 381  382  71.0  70.0  1.025  0.0  0.0   79.0   47.0  0.50  142.0 ...
# 382  383  48.0  80.0  1.025  0.0  0.0   75.0   22.0  0.80  137.0 ...
# 383  384  80.0  80.0  1.025  0.0  0.0  119.0   46.0  0.70  141.0 ...
# 384  385  57.0  60.0  1.020  0.0  0.0  132.0   18.0  1.10  150.0 ...
# 385  386  63.0  70.0  1.020  0.0  0.0  113.0   25.0  0.60  146.0 ...
# 386  387  46.0  70.0  1.025  0.0  0.0  100.0   47.0  0.50  142.0 ...
# 387  388  15.0  80.0  1.025  0.0  0.0   93.0   17.0  0.90  136.0 ...
# 388  389  51.0  80.0  1.020  0.0  0.0   94.0   15.0  1.20  144.0 ...
# 389  390  41.0  80.0  1.025  0.0  0.0  112.0   48.0  0.70  140.0 ...
# 390  391  52.0  80.0  1.025  0.0  0.0   99.0   25.0  0.80  135.0 ...
# 391  392  36.0  80.0  1.025  0.0  0.0   85.0   16.0  1.10  142.0 ...
# 392  393  57.0  80.0  1.020  0.0  0.0  133.0   48.0  1.20  147.0 ...
# 393  394  43.0  60.0  1.025  0.0  0.0  117.0   45.0  0.70  141.0 ...
# 394  395  50.0  80.0  1.020  0.0  0.0  137.0   46.0  0.80  139.0 ...
# 395  396  55.0  80.0  1.020  0.0  0.0  140.0   49.0  0.50  150.0 ...
# 396  397  42.0  70.0  1.025  0.0  0.0   75.0   31.0  1.20  141.0 ...
# 397  398  12.0  80.0  1.020  0.0  0.0  100.0   26.0  0.60  137.0 ...
# 398  399  17.0  60.0  1.025  0.0  0.0  114.0   50.0  1.00  135.0 ...
# 399  400  58.0  80.0  1.025  0.0  0.0  131.0   18.0  1.10  141.0 ...
#
#           rbc        pc         pcc          ba  htn   dm  cad appet   pe  ane
# 0         NaN    normal  notpresent  notpresent  yes  yes   no  good   no   no
# 4      normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 5         NaN       NaN  notpresent  notpresent  yes  yes   no  good  yes   no
# 13        NaN       NaN  notpresent  notpresent  yes  yes  yes  poor  yes   no
# 16        NaN    normal  notpresent  notpresent   no   no   no  good   no   no
# 17        NaN       NaN  notpresent  notpresent  yes   no   no  poor   no   no
# 19        NaN  abnormal     present  notpresent  yes   no  yes  good   no   no
# 23        NaN    normal  notpresent  notpresent   no   no   no  poor   no  yes
# 25        NaN    normal  notpresent  notpresent  yes  yes   no  good   no  yes
# 26        NaN    normal  notpresent  notpresent  yes  yes   no  poor   no   no
# 29   abnormal  abnormal     present  notpresent   no   no  yes  good   no   no
# 31        NaN  abnormal     present  notpresent   no   no   no  poor   no   no
# 36     normal    normal  notpresent  notpresent  yes   no   no  good   no   no
# 37        NaN       NaN  notpresent  notpresent  yes  yes   no  poor   no  yes
# 38   abnormal    normal  notpresent  notpresent  yes   no   no  good   no   no
# 40     normal  abnormal  notpresent  notpresent  yes   no   no  good   no   no
# 41        NaN    normal  notpresent  notpresent   no   no   no  good  yes   no
# 46        NaN    normal  notpresent  notpresent   no  yes   no  good   no   no
# 47        NaN    normal  notpresent  notpresent   no   no   no  good   no   no
# 50        NaN       NaN  notpresent  notpresent  yes  yes   no  poor  yes  yes
# 52        NaN    normal  notpresent  notpresent   no   no   no  poor   no  yes
# 55   abnormal    normal  notpresent  notpresent   no   no   no  good  yes   no
# 62        NaN    normal  notpresent  notpresent  yes  yes   no  good   no   no
# 64        NaN    normal  notpresent  notpresent   no   no   no  good   no   no
# 65        NaN    normal  notpresent  notpresent   no   no   no  good   no   no
# 66   abnormal    normal  notpresent  notpresent  yes  yes   no  good  yes   no
# 68        NaN    normal     present  notpresent   no   no   no  good   no   no
# 71     normal    normal  notpresent  notpresent  yes  yes   no  good   no   no
# 77        NaN    normal  notpresent  notpresent  yes  yes   no  good  yes   no
# 78        NaN       NaN  notpresent  notpresent  yes   no   no  good  yes   no
# ..        ...       ...         ...         ...  ...  ...  ...   ...  ...  ...
# 370    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 371    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 372    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 373    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 374    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 375    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 376    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 377    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 378    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 379    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 380    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 381       NaN       NaN  notpresent  notpresent   no   no   no  good   no   no
# 382    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 383    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 384    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 385    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 386    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 387    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 388    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 389    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 390    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 391    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 392    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 393    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 394    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 395    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 396    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 397    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 398    normal    normal  notpresent  notpresent   no   no   no  good   no   no
# 399    normal    normal  notpresent  notpresent   no   no   no  good   no   no
#
# [251 rows x 25 columns]

# %%
filtered_df = filtered_df.replace({"rbc": {"normal": 0, "abnormal": 1}})

# %%
filtered_df.head(15)
# Out:
#     id   age    bp     sg   al   su    bgr     bu   sc    sod ...   rbc  \
# 0    1  48.0  80.0  1.020  1.0  0.0  121.0   36.0  1.2    NaN ...   NaN
# 4    5  51.0  80.0  1.010  2.0  0.0  106.0   26.0  1.4    NaN ...   0.0
# 5    6  60.0  90.0  1.015  3.0  0.0   74.0   25.0  1.1  142.0 ...   NaN
# 13  14  68.0  70.0    NaN  NaN  NaN   98.0   86.0  4.6  135.0 ...   NaN
# 16  17  47.0  70.0  1.015  2.0  0.0   99.0   46.0  2.2  138.0 ...   NaN
# 17  18  47.0  80.0    NaN  NaN  NaN  114.0   87.0  5.2  139.0 ...   NaN
# 19  20  62.0  60.0  1.015  1.0  0.0  100.0   31.0  1.6    NaN ...   NaN
# 23  24  21.0  70.0  1.010  0.0  0.0    NaN    NaN  NaN    NaN ...   NaN
# 25  26  61.0  60.0  1.025  0.0  0.0  108.0   75.0  1.9  141.0 ...   NaN
# 26  27  75.0  80.0  1.015  0.0  0.0  156.0   45.0  2.4  140.0 ...   NaN
# 29  30  68.0  70.0  1.005  1.0  0.0    NaN   28.0  1.4    NaN ...   1.0
# 31  32  73.0  90.0  1.015  3.0  0.0  107.0   33.0  1.5  141.0 ...   NaN
# 36  37  76.0  70.0  1.015  1.0  0.0   92.0   29.0  1.8  133.0 ...   0.0
# 37  38  72.0  80.0    NaN  NaN  NaN  137.0   65.0  3.4  141.0 ...   NaN
# 38  39  69.0  80.0  1.020  3.0  0.0    NaN  103.0  4.1  132.0 ...   1.0
#
#           pc         pcc          ba  htn   dm  cad appet   pe  ane
# 0     normal  notpresent  notpresent  yes  yes   no  good   no   no
# 4     normal  notpresent  notpresent   no   no   no  good   no   no
# 5        NaN  notpresent  notpresent  yes  yes   no  good  yes   no
# 13       NaN  notpresent  notpresent  yes  yes  yes  poor  yes   no
# 16    normal  notpresent  notpresent   no   no   no  good   no   no
# 17       NaN  notpresent  notpresent  yes   no   no  poor   no   no
# 19  abnormal     present  notpresent  yes   no  yes  good   no   no
# 23    normal  notpresent  notpresent   no   no   no  poor   no  yes
# 25    normal  notpresent  notpresent  yes  yes   no  good   no  yes
# 26    normal  notpresent  notpresent  yes  yes   no  poor   no   no
# 29  abnormal     present  notpresent   no   no  yes  good   no   no
# 31  abnormal     present  notpresent   no   no   no  poor   no   no
# 36    normal  notpresent  notpresent  yes   no   no  good   no   no
# 37       NaN  notpresent  notpresent  yes  yes   no  poor   no  yes
# 38    normal  notpresent  notpresent  yes   no   no  good   no   no
#
# [15 rows x 25 columns]

# %%
filtered_df["pc"].dtypes
# Out:
# dtype('O')

# %%
filtered_df.pc.unique()
# Out:
# array(['normal', nan, 'abnormal'], dtype=object)

# %%
filtered_df["pc"].unique()
# Out:
# array(['normal', nan, 'abnormal'], dtype=object)

# %%
a = filtered_df["pc"]
a.head()
# Out:
# 0     normal
# 4     normal
# 5        NaN
# 13       NaN
# 16    normal
# Name: pc, dtype: object

# %%
for x in a.unique():
    print(x)
# Out:
# normal
# nan
# abnormal

# %%
c = a.unique()
type(c)
# Out:
# numpy.ndarray

# %%
d = c.tolist()
d
# Out:
# ['normal', nan, 'abnormal']

# %%
e = [x for x in d if str(x) != 'nan']
e
# Out:
# ['normal', 'abnormal']

# %%
import math
b = []
count = 0
# c = c[~np.isnan(c)]

for x in e:
    b.append(count)
    count+=1
b
# Out:
# [0, 1]

# %%
filtered_df.pc.unique()
# Out:
# array(['normal', nan, 'abnormal'], dtype=object)

# %%
def encode(df, column):
    a = df[column].unique().tolist()
    c = [x for x in a if str(x) != 'nan']
    
    l=[]
    i=0
    for x in c:
        l.append(i)
        i+=1
        
    df[column] = df[column].replace(c, l)

    return df
encode(filtered_df, "ba")
# Out:
#       id   age    bp     sg   al   su    bgr     bu    sc    sod ...   rbc  \
# 0      1  48.0  80.0  1.020  1.0  0.0  121.0   36.0  1.20    NaN ...   NaN
# 4      5  51.0  80.0  1.010  2.0  0.0  106.0   26.0  1.40    NaN ...   0.0
# 5      6  60.0  90.0  1.015  3.0  0.0   74.0   25.0  1.10  142.0 ...   NaN
# 13    14  68.0  70.0    NaN  NaN  NaN   98.0   86.0  4.60  135.0 ...   NaN
# 16    17  47.0  70.0  1.015  2.0  0.0   99.0   46.0  2.20  138.0 ...   NaN
# 17    18  47.0  80.0    NaN  NaN  NaN  114.0   87.0  5.20  139.0 ...   NaN
# 19    20  62.0  60.0  1.015  1.0  0.0  100.0   31.0  1.60    NaN ...   NaN
# 23    24  21.0  70.0  1.010  0.0  0.0    NaN    NaN   NaN    NaN ...   NaN
# 25    26  61.0  60.0  1.025  0.0  0.0  108.0   75.0  1.90  141.0 ...   NaN
# 26    27  75.0  80.0  1.015  0.0  0.0  156.0   45.0  2.40  140.0 ...   NaN
# 29    30  68.0  70.0  1.005  1.0  0.0    NaN   28.0  1.40    NaN ...   1.0
# 31    32  73.0  90.0  1.015  3.0  0.0  107.0   33.0  1.50  141.0 ...   NaN
# 36    37  76.0  70.0  1.015  1.0  0.0   92.0   29.0  1.80  133.0 ...   0.0
# 37    38  72.0  80.0    NaN  NaN  NaN  137.0   65.0  3.40  141.0 ...   NaN
# 38    39  69.0  80.0  1.020  3.0  0.0    NaN  103.0  4.10  132.0 ...   1.0
# 40    41  46.0  90.0  1.010  2.0  0.0   99.0   80.0  2.10    NaN ...   0.0
# 41    42  45.0  70.0  1.010  0.0  0.0    NaN   20.0  0.70    NaN ...   NaN
# 46    47  48.0  70.0  1.015  0.0  0.0  124.0   24.0  1.20  142.0 ...   NaN
# 47    48  11.0  80.0  1.010  3.0  0.0    NaN   17.0  0.80    NaN ...   NaN
# 50    51  53.0  60.0    NaN  NaN  NaN   91.0  114.0  3.25  142.0 ...   NaN
# 52    53  53.0  90.0  1.015  0.0  0.0    NaN   38.0  2.20    NaN ...   NaN
# 55    56  35.0  80.0  1.005  3.0  0.0    NaN    NaN   NaN    NaN ...   1.0
# 62    63  15.0  60.0  1.020  3.0  0.0   86.0   15.0  0.60  138.0 ...   NaN
# 64    65  55.0  80.0  1.010  0.0  0.0  146.0    NaN   NaN    NaN ...   NaN
# 65    66  44.0  90.0  1.010  1.0  0.0    NaN   20.0  1.10    NaN ...   NaN
# 66    67  67.0  70.0  1.020  2.0  0.0  150.0   55.0  1.60  131.0 ...   1.0
# 68    69  65.0  70.0  1.010  2.0  0.0  112.0   73.0  3.30    NaN ...   NaN
# 71    72  46.0  60.0  1.010  1.0  0.0  163.0   92.0  3.30  141.0 ...   0.0
# 77    78  67.0  70.0  1.010  1.0  0.0  102.0   48.0  3.20  137.0 ...   NaN
# 78    79  70.0  80.0    NaN  NaN  NaN  158.0   85.0  3.20  141.0 ...   NaN
# ..   ...   ...   ...    ...  ...  ...    ...    ...   ...    ... ...   ...
# 370  371  69.0  70.0  1.020  0.0  0.0   83.0   42.0  1.20  139.0 ...   0.0
# 371  372  28.0  60.0  1.025  0.0  0.0   79.0   50.0  0.50  145.0 ...   0.0
# 372  373  72.0  60.0  1.020  0.0  0.0  109.0   26.0  0.90  150.0 ...   0.0
# 373  374  61.0  70.0  1.025  0.0  0.0  133.0   38.0  1.00  142.0 ...   0.0
# 374  375  79.0  80.0  1.025  0.0  0.0  111.0   44.0  1.20  146.0 ...   0.0
# 375  376  70.0  80.0  1.020  0.0  0.0   74.0   41.0  0.50  143.0 ...   0.0
# 376  377  58.0  70.0  1.025  0.0  0.0   88.0   16.0  1.10  147.0 ...   0.0
# 377  378  64.0  70.0  1.020  0.0  0.0   97.0   27.0  0.70  145.0 ...   0.0
# 378  379  71.0  60.0  1.025  0.0  0.0    NaN    NaN  0.90  140.0 ...   0.0
# 379  380  62.0  80.0  1.025  0.0  0.0   78.0   45.0  0.60  138.0 ...   0.0
# 380  381  59.0  60.0  1.020  0.0  0.0  113.0   23.0  1.10  139.0 ...   0.0
# 381  382  71.0  70.0  1.025  0.0  0.0   79.0   47.0  0.50  142.0 ...   NaN
# 382  383  48.0  80.0  1.025  0.0  0.0   75.0   22.0  0.80  137.0 ...   0.0
# 383  384  80.0  80.0  1.025  0.0  0.0  119.0   46.0  0.70  141.0 ...   0.0
# 384  385  57.0  60.0  1.020  0.0  0.0  132.0   18.0  1.10  150.0 ...   0.0
# 385  386  63.0  70.0  1.020  0.0  0.0  113.0   25.0  0.60  146.0 ...   0.0
# 386  387  46.0  70.0  1.025  0.0  0.0  100.0   47.0  0.50  142.0 ...   0.0
# 387  388  15.0  80.0  1.025  0.0  0.0   93.0   17.0  0.90  136.0 ...   0.0
# 388  389  51.0  80.0  1.020  0.0  0.0   94.0   15.0  1.20  144.0 ...   0.0
# 389  390  41.0  80.0  1.025  0.0  0.0  112.0   48.0  0.70  140.0 ...   0.0
# 390  391  52.0  80.0  1.025  0.0  0.0   99.0   25.0  0.80  135.0 ...   0.0
# 391  392  36.0  80.0  1.025  0.0  0.0   85.0   16.0  1.10  142.0 ...   0.0
# 392  393  57.0  80.0  1.020  0.0  0.0  133.0   48.0  1.20  147.0 ...   0.0
# 393  394  43.0  60.0  1.025  0.0  0.0  117.0   45.0  0.70  141.0 ...   0.0
# 394  395  50.0  80.0  1.020  0.0  0.0  137.0   46.0  0.80  139.0 ...   0.0
# 395  396  55.0  80.0  1.020  0.0  0.0  140.0   49.0  0.50  150.0 ...   0.0
# 396  397  42.0  70.0  1.025  0.0  0.0   75.0   31.0  1.20  141.0 ...   0.0
# 397  398  12.0  80.0  1.020  0.0  0.0  100.0   26.0  0.60  137.0 ...   0.0
# 398  399  17.0  60.0  1.025  0.0  0.0  114.0   50.0  1.00  135.0 ...   0.0
# 399  400  58.0  80.0  1.025  0.0  0.0  131.0   18.0  1.10  141.0 ...   0.0
#
#            pc         pcc   ba  htn   dm  cad appet   pe  ane
# 0      normal  notpresent  0.0  yes  yes   no  good   no   no
# 4      normal  notpresent  0.0   no   no   no  good   no   no
# 5         NaN  notpresent  0.0  yes  yes   no  good  yes   no
# 13        NaN  notpresent  0.0  yes  yes  yes  poor  yes   no
# 16     normal  notpresent  0.0   no   no   no  good   no   no
# 17        NaN  notpresent  0.0  yes   no   no  poor   no   no
# 19   abnormal     present  0.0  yes   no  yes  good   no   no
# 23     normal  notpresent  0.0   no   no   no  poor   no  yes
# 25     normal  notpresent  0.0  yes  yes   no  good   no  yes
# 26     normal  notpresent  0.0  yes  yes   no  poor   no   no
# 29   abnormal     present  0.0   no   no  yes  good   no   no
# 31   abnormal     present  0.0   no   no   no  poor   no   no
# 36     normal  notpresent  0.0  yes   no   no  good   no   no
# 37        NaN  notpresent  0.0  yes  yes   no  poor   no  yes
# 38     normal  notpresent  0.0  yes   no   no  good   no   no
# 40   abnormal  notpresent  0.0  yes   no   no  good   no   no
# 41     normal  notpresent  0.0   no   no   no  good  yes   no
# 46     normal  notpresent  0.0   no  yes   no  good   no   no
# 47     normal  notpresent  0.0   no   no   no  good   no   no
# 50        NaN  notpresent  0.0  yes  yes   no  poor  yes  yes
# 52     normal  notpresent  0.0   no   no   no  poor   no  yes
# 55     normal  notpresent  0.0   no   no   no  good  yes   no
# 62     normal  notpresent  0.0  yes  yes   no  good   no   no
# 64     normal  notpresent  0.0   no   no   no  good   no   no
# 65     normal  notpresent  0.0   no   no   no  good   no   no
# 66     normal  notpresent  0.0  yes  yes   no  good  yes   no
# 68     normal     present  0.0   no   no   no  good   no   no
# 71     normal  notpresent  0.0  yes  yes   no  good   no   no
# 77     normal  notpresent  0.0  yes  yes   no  good  yes   no
# 78        NaN  notpresent  0.0  yes   no   no  good  yes   no
# ..        ...         ...  ...  ...  ...  ...   ...  ...  ...
# 370    normal  notpresent  0.0   no   no   no  good   no   no
# 371    normal  notpresent  0.0   no   no   no  good   no   no
# 372    normal  notpresent  0.0   no   no   no  good   no   no
# 373    normal  notpresent  0.0   no   no   no  good   no   no
# 374    normal  notpresent  0.0   no   no   no  good   no   no
# 375    normal  notpresent  0.0   no   no   no  good   no   no
# 376    normal  notpresent  0.0   no   no   no  good   no   no
# 377    normal  notpresent  0.0   no   no   no  good   no   no
# 378    normal  notpresent  0.0   no   no   no  good   no   no
# 379    normal  notpresent  0.0   no   no   no  good   no   no
# 380    normal  notpresent  0.0   no   no   no  good   no   no
# 381       NaN  notpresent  0.0   no   no   no  good   no   no
# 382    normal  notpresent  0.0   no   no   no  good   no   no
# 383    normal  notpresent  0.0   no   no   no  good   no   no
# 384    normal  notpresent  0.0   no   no   no  good   no   no
# 385    normal  notpresent  0.0   no   no   no  good   no   no
# 386    normal  notpresent  0.0   no   no   no  good   no   no
# 387    normal  notpresent  0.0   no   no   no  good   no   no
# 388    normal  notpresent  0.0   no   no   no  good   no   no
# 389    normal  notpresent  0.0   no   no   no  good   no   no
# 390    normal  notpresent  0.0   no   no   no  good   no   no
# 391    normal  notpresent  0.0   no   no   no  good   no   no
# 392    normal  notpresent  0.0   no   no   no  good   no   no
# 393    normal  notpresent  0.0   no   no   no  good   no   no
# 394    normal  notpresent  0.0   no   no   no  good   no   no
# 395    normal  notpresent  0.0   no   no   no  good   no   no
# 396    normal  notpresent  0.0   no   no   no  good   no   no
# 397    normal  notpresent  0.0   no   no   no  good   no   no
# 398    normal  notpresent  0.0   no   no   no  good   no   no
# 399    normal  notpresent  0.0   no   no   no  good   no   no
#
# [251 rows x 25 columns]
